# %% [markdown]
# # Querying with SQLAlchemy - Lab
#
# ## Introduction
#
# In this lesson, we'll learn how to use SQLAlchemy to write queries about Microsoft's _Northwind Traders_ database!
#
# ## Objectives
#
# You will be able to:
#
# * Read and understand an ERD diagram
# * Create queries with SQLAlchemy, including queries that involve many-to-many relationships
#
# ## Getting Started
#
# In order to complete this lab, we'll need to download a SQLite3-compatible version of the _Northwind Traders_ database from Microsoft.  Microsoft built this database back in the year 2000 to help showcase their SQL Server technology. Since then, it has been open-sourced and has become a great practice tool for every new generation of SQL learners.
#
# Lucky for us, some generous programmers have already converted the Northwind database to a sqlite-compatible version and posted it on Github. We've already included the file the SQL database file that we'll be working with in the repo for this folder, along with the following ERD Diagram. However, if you would like to work with the larger version of this dataset at a future time, just clone [this repo](https://github.com/jpwhite3/northwind-SQLite3) and follow their instructions to access it!
#
# ## ERD Diagram For Northwind Traders
#
# The following ERD Diagram describes the Northwind Traders Database:
#
# <img src='Northwind_ERD.png'>
#
# If the text seems a bit hard to read inside this jupyter notebook, just go into the folder for this repo and open the `Northwind_ERD.png` file manually to see it full size.
#
# ## Connecting to the Database
#
# The first thing we'll need to do is connect to the Northwind Traders database, which can be found in the file `Northwind_small.sqlite`.
#
# In the cell below, import the necessary tools from the `sqlalchemy` library, and take the necessary steps to connect to the database.
#
# **_NOTE:_** We won't be modifying the information in the database at all, just querying it, so there's no need to import the various things you would need to create declarative base classes and the like.

# %%
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy.orm import Session, sessionmaker

engine = create_engine('sqlite:///Northwind_small.sqlite',echo=True)
Session = sessionmaker(bind=engine)
session = Session()

# %% [markdown]
# ## Get Table Names and Table Information
#
# One of the most useful things we can do when working with a new database is to inspect the tables until we have a solid idea of what we're looking at.  As you work through this lab, you'll notice that there are some small discrepancies between the Table/Column names listed in the ERD and what they are actually are in the database.  This may be annoying, but this is not an accident--sometimes, documentation is wrong!  By learning how to inspect what tables exist in a database, as well as how which columns exist inside a table, we can save ourselves a lot of headaches by double checking.
#
# In the cell below:
#
# * Import `inspect` from sqlalchemy
# * Create an inspector object by passing in `engine` to `inspect`
# * Use the appropriate inspector function to get the names of all tables

# %%
from sqlalchemy import inspect

inspector = inspect(engine)

print(inspector.get_table_names())
# Out:
# 2018-12-02 15:53:01,109 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2018-12-02 15:53:01,110 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:01,112 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2018-12-02 15:53:01,114 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:01,117 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2018-12-02 15:53:01,118 INFO sqlalchemy.engine.base.Engine ()
# ['Category', 'Customer', 'CustomerCustomerDemo', 'CustomerDemographic', 'Employee', 'EmployeeTerritory', 'Order', 'OrderDetail', 'Product', 'Region', 'Shipper', 'Supplier', 'Territory']

# %% [markdown]
# Great! We can now see exactly what each Table is named.
#
# **_Question_**:
#
# Are there any discrepancies between the table names and the ERD diagrams? if so, what are they?
#
# Write your answer below this line:
# ________________________________________________________________________________________________________________________________
#
# The plurality of most of the table names do not match the ERD diagrams.
#
# Let's inspect the column names on one of the tables as well. In the cell below, call the appropriate method to get all column names for the `'Employee'` table.

# %%
print(inspector.get_columns('Employee'))
# Out:
# 2018-12-02 15:53:03,671 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Employee")
# 2018-12-02 15:53:03,675 INFO sqlalchemy.engine.base.Engine ()
# [{'name': 'Id', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 1}, {'name': 'LastName', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'FirstName', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'Title', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'TitleOfCourtesy', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'BirthDate', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'HireDate', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'Address', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'City', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'Region', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'PostalCode', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'Country', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'HomePhone', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'Extension', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'Photo', 'type': BLOB(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'Notes', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'ReportsTo', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'PhotoPath', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}]

# %% [markdown]
# That output is good, but its a bit messy. Let's write a function that makes it a bit more readable, and only tells us what we need to know.
#
# The current structure of the output is a list of dictionaries. Complete the function below so that when the function is called and passed a table name, it prints out the name and type of each column in a well-formatted way.

# %%
def get_columns_info(table_name):
    cols_list = inspector.get_columns(table_name)
    
    print("Table Name: {}".format(table_name))
    print("")
    
    for i in cols_list:
        print("Name: {} \t Type: {}".format(i['name'], i['type']))

get_columns_info('Employee')
# Out:
# Table Name: Employee
#
# Name: Id 	 Type: INTEGER
# Name: LastName 	 Type: VARCHAR(8000)
# Name: FirstName 	 Type: VARCHAR(8000)
# Name: Title 	 Type: VARCHAR(8000)
# Name: TitleOfCourtesy 	 Type: VARCHAR(8000)
# Name: BirthDate 	 Type: VARCHAR(8000)
# Name: HireDate 	 Type: VARCHAR(8000)
# Name: Address 	 Type: VARCHAR(8000)
# Name: City 	 Type: VARCHAR(8000)
# Name: Region 	 Type: VARCHAR(8000)
# Name: PostalCode 	 Type: VARCHAR(8000)
# Name: Country 	 Type: VARCHAR(8000)
# Name: HomePhone 	 Type: VARCHAR(8000)
# Name: Extension 	 Type: VARCHAR(8000)
# Name: Photo 	 Type: BLOB
# Name: Notes 	 Type: VARCHAR(8000)
# Name: ReportsTo 	 Type: INTEGER
# Name: PhotoPath 	 Type: VARCHAR(8000)

# %% [raw]
# # Expected Output:
#
# Table Name: Employee
#
# Name: Id 	 Type: INTEGER
# Name: LastName 	 Type: VARCHAR(8000)
# Name: FirstName 	 Type: VARCHAR(8000)
# Name: Title 	 Type: VARCHAR(8000)
# Name: TitleOfCourtesy 	 Type: VARCHAR(8000)
# Name: BirthDate 	 Type: VARCHAR(8000)
# Name: HireDate 	 Type: VARCHAR(8000)
# Name: Address 	 Type: VARCHAR(8000)
# Name: City 	 Type: VARCHAR(8000)
# Name: Region 	 Type: VARCHAR(8000)
# Name: PostalCode 	 Type: VARCHAR(8000)
# Name: Country 	 Type: VARCHAR(8000)
# Name: HomePhone 	 Type: VARCHAR(8000)
# Name: Extension 	 Type: VARCHAR(8000)
# Name: Photo 	 Type: BLOB
# Name: Notes 	 Type: VARCHAR(8000)
# Name: ReportsTo 	 Type: INTEGER
# Name: PhotoPath 	 Type: VARCHAR(8000)

# %% [markdown]
# ## Connecting and Executing Raw SQL Statements
#
# Sometimes, the easiest thing for us to do is to just execute a raw SQL statement.  This is very easy with SQLAlchemy--we just need to establish a connection, and then use the appropriat methods to execute SQL statements!
#
# In the cell below:
#
# * Create a connection using the `engine` object's appropriate method and store it in the variable `con`
# * Use the appropriate method from `con` to execute a raw SQL statement (in the form of a string) that gets everything from the `'Customer'` table with a LIMIT of 5. Store the results returned in the variable `rs`
# * Use the `fetchall()` method to display all results from `rs`.

# %%
con = engine.connect()
rs = con.execute('SELECT * FROM customer LIMIT 5')

rs.fetchall()
# Out:
# 2018-12-02 15:53:10,439 INFO sqlalchemy.engine.base.Engine SELECT * FROM customer LIMIT 5
# 2018-12-02 15:53:10,442 INFO sqlalchemy.engine.base.Engine ()
# [('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Sales Representative', 'Obere Str. 57', 'Berlin', 'Western Europe', '12209', 'Germany', '030-0074321', '030-0076545'),
#  ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Owner', 'Avda. de la Constitución 2222', 'México D.F.', 'Central America', '05021', 'Mexico', '(5) 555-4729', '(5) 555-3745'),
#  ('ANTON', 'Antonio Moreno Taquería', 'Antonio Moreno', 'Owner', 'Mataderos  2312', 'México D.F.', 'Central America', '05023', 'Mexico', '(5) 555-3932', None),
#  ('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', 'British Isles', 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'),
#  ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Order Administrator', 'Berguvsvägen  8', 'Luleå', 'Northern Europe', 'S-958 22', 'Sweden', '0921-12 34 65', '0921-12 34 67')]

# %% [raw]
# # Expected Output:
#
# [('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Sales Representative', 'Obere Str. 57', 'Berlin', 'Western Europe', '12209', 'Germany', '030-0074321', '030-0076545'), ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Owner', 'Avda. de la Constitución 2222', 'México D.F.', 'Central America', '05021', 'Mexico', '(5) 555-4729', '(5) 555-3745'), ('ANTON', 'Antonio Moreno Taquería', 'Antonio Moreno', 'Owner', 'Mataderos  2312', 'México D.F.', 'Central America', '05023', 'Mexico', '(5) 555-3932', None), ('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', 'British Isles', 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'), ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Order Administrator', 'Berguvsvägen  8', 'Luleå', 'Northern Europe', 'S-958 22', 'Sweden', '0921-12 34 65', '0921-12 34 67')]

# %% [markdown]
# ## Incorporating Pandas DataFrames
#
# So far we've been able to easily connect to a SQL database, inspect the tables, and execute queries. However, the results returned from queries haven't been in an easily readable format.  We'll fix that by taking the results and storing it in a pandas DataFrame!
#
# In the cell below:
#
# * Import pandas and set the standard alias.
# * Create and execute a query that gets The firstname, lastname, and title of every person in the `'Employee'` table.
# * Create a pandas DataFrame out of the results returned from `rs.fetchall()`
# * Display the head of the new DataFRame

# %%
import pandas as pd

rs = con.execute('SELECT firstname, lastname, title FROM employee')
df = pd.DataFrame(rs.fetchall())
df.head()
# Out:
# 2018-12-02 15:53:13,598 INFO sqlalchemy.engine.base.Engine SELECT firstname, lastname, title FROM employee
# 2018-12-02 15:53:13,599 INFO sqlalchemy.engine.base.Engine ()
#           0          1                      2
# 0     Nancy    Davolio   Sales Representative
# 1    Andrew     Fuller  Vice President, Sales
# 2     Janet  Leverling   Sales Representative
# 3  Margaret    Peacock   Sales Representative
# 4    Steven   Buchanan          Sales Manager

# %% [markdown]
# Nice! We can now read our results.  However, the columns of our DataFrame aren't labeled.  Luckily, pandas plays nicely with the sqlalchemy library, and can actually execute sql queries!

# %% [markdown]
# ### Writing Queries with Pandas
#
# In the cell below:
#
# * Use the appropriate method from pandas to select all columns for every row in the `[Order]` table where the customer is `'VINET'`
# * Be sure to pass in our `engine` as the 2nd parameter, otherwise it won't work!
# * Display the head of the DataFrame created to ensure everything worked correctly.

# %%
df = pd.read_sql_query('SELECT * FROM [Order] WHERE customerid IS "VINET" ',engine)
df.head()
# Out:
# 2018-12-02 15:53:18,821 INFO sqlalchemy.engine.base.Engine SELECT * FROM [Order] WHERE customerid IS "VINET"
# 2018-12-02 15:53:18,822 INFO sqlalchemy.engine.base.Engine ()
#       Id CustomerId  EmployeeId   OrderDate RequiredDate ShippedDate  ShipVia  \
# 0  10248      VINET           5  2012-07-04   2012-08-01  2012-07-16        3
# 1  10274      VINET           6  2012-08-06   2012-09-03  2012-08-16        1
# 2  10295      VINET           2  2012-09-02   2012-09-30  2012-09-10        2
# 3  10737      VINET           2  2013-11-11   2013-12-09  2013-11-18        2
# 4  10739      VINET           3  2013-11-12   2013-12-10  2013-11-17        3
#
#    Freight                   ShipName         ShipAddress ShipCity  \
# 0    32.38  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
# 1     6.01  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
# 2     1.15  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
# 3     7.79  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
# 4    11.08  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
#
#        ShipRegion ShipPostalCode ShipCountry
# 0  Western Europe          51100      France
# 1  Western Europe          51100      France
# 2  Western Europe          51100      France
# 3  Western Europe          51100      France
# 4  Western Europe          51100      France

# %% [markdown]
# Great! As we can see from the output above, when we let pandas execute the SQL query for us, the DataFrame now contains columns with the correct labels. This is a great way to execute SQL while still making sure our results are easy to read and manipulate by using DataFrames!
#
# ## Executing JOIN Statements
#
# Let's try executing a JOIN statement inside `pd.read_sql_query`.
#
# In the cell below:
#
# * Write a query that gets the Order ID, Company Name, and the total count of orders made by each company (as num_orders).
# * Group the results by Company Name
# * Order the results by num_orders, descending
# * Display the head of the DataFrame to ensure everything worked correctly.

# %%
df = pd.read_sql_query('SELECT [order].Id, \
                               companyName, \
                               COUNT([order].customerId) AS num_orders \
                               FROM [customer] JOIN [order] ON [customer].Id = [order].customerId \
                               GROUP BY customerId \
                               ORDER BY num_orders DESC',engine)
df.head()
# Out:
# 2018-12-02 15:53:24,873 INFO sqlalchemy.engine.base.Engine SELECT [order].Id,                                companyName,                                COUNT([order].customerId) AS num_orders                                FROM [customer] JOIN [order] ON [customer].Id = [order].customerId                                GROUP BY customerId                                ORDER BY num_orders DESC
# 2018-12-02 15:53:24,874 INFO sqlalchemy.engine.base.Engine ()
#       Id                   CompanyName  num_orders
# 0  11064            Save-a-lot Markets          31
# 1  11072                  Ernst Handel          30
# 2  11021                    QUICK-Stop          28
# 3  11050                Folk och fä HB          19
# 4  11063  Hungry Owl All-Night Grocers          19

# %% [markdown]
# ### Expected Output
#
# <img src='join_results.png'>
#
# Great job! Let's see if we can execute a join that includes entities with a many-to-many relationship.
#
# ### JOINs with Many-To-Many Relationships
#
# In the cell below:
#
# * Write a query that selects the LastName, FirstName and number of territories assigned for every employee.
# * Group the results by employee lastname
# * Order by the total number of territories assigned to each employee, descending
# * You'll need to make use a join table to solve this one--be sure to take a look at the ERD diagram again if needed!
# * Store your results in a DataFrame and display the head to ensure that everything worked correctly.
#
# **_NOTE:_** For long SQL statements, consider using the multiline string format in python, denoted by `"""three quotes"""` at the beginning and end.  Note that if you hit enter to move to another line, be sure to add an `\` character at the end of the line to escape it--otherwise, your sql statements will contain `\n` newline characters wherever you hit enter to move to the next line.

# %%
q = 'SELECT LastName, FirstName, COUNT(employeeId) AS TerritoriesAssigned \
            FROM employee JOIN employeeterritory ON employee.id = employeeId \
            GROUP BY LastName \
            ORDER BY TerritoriesAssigned DESC'

df2 = pd.read_sql_query(q, engine)
df2.head()
# Out:
# 2018-12-02 15:53:29,312 INFO sqlalchemy.engine.base.Engine SELECT LastName, FirstName, COUNT(employeeId) AS TerritoriesAssigned             FROM employee JOIN employeeterritory ON employee.id = employeeId             GROUP BY LastName             ORDER BY TerritoriesAssigned DESC
# 2018-12-02 15:53:29,316 INFO sqlalchemy.engine.base.Engine ()
#     LastName FirstName  TerritoriesAssigned
# 0       King    Robert                   10
# 1   Buchanan    Steven                    7
# 2  Dodsworth      Anne                    7
# 3     Fuller    Andrew                    7
# 4     Suyama   Michael                    5

# %% [markdown]
# #### Expected Output:
#
# <img src='many-to-many-results.png'>

# %% [markdown]
# Great job! You've demonstrated proficiency using raw sql with SQLAlchemy. However, we haven't yet touched all the fun declarative stuff.  Let's get some practice working with SQLAlchemy `session` objects below!
#
# ## Using SQLAlchemy Sessions
#
# So far, we've just been using SQLAlchemy as a way to connect to a database and run SQL queries. However, SQLAlchemy is an **_Object-Relational Mapper_**, and can map entities in our database to python objects! This can be incredibly helpful when we need to incorporate data from our database into an object-oriented program or model.
#
# Let's start by getting some practice with `session` objects, because that's where all the magic happens.
#
# ### Using `.query` Objects
#
# Recall that we created a `session` object at the beginning of this lab by using SQLAlchemy's `sessionmaker` function and binding it to our `engine` object.  We haven't used our `session` object too much thus far, but now we'll use it for queries!
#
# The `session` object contains a `.query()` method which returns a query object containing the results of our query, with the results mapped to objects.
#
# Before we can make use of Object-Relational Mappings, we need to make sure that we have mappings created that map the tables in our existing database to objects in python.  We don't want to have to do this manually, so we'll make use the `automap` module inside of `sqlalchemy.ext`.
#
# In the cell below:
#
# * Import `MetaData` from `sqlalchemy`
# * Import `automap_base` from `sqlalchemy.ext.automap`
# * Create a `MetaData` object
# * Use the metadata object's `reflect` method on our `engine`
# * Call `automap_base` and set the `metadata` parameter to our `metadata`. Store the results returned inside of the variable `Base`
# * Call `base.prepare()`
# * Map `Employee` and `Customer` to the `Employee` and `Customer` classes, which can be found inside of `Base.classes`

# %%
from sqlalchemy import MetaData
from sqlalchemy.ext.automap import automap_base

metadata = MetaData()

metadata.reflect(engine)

Base = automap_base(metadata=metadata)
Base.prepare()
# Don't forget to .prepare()!

Employee, Customer = Base.classes.Employee , Base.classes.Customer
# Out:
# 2018-12-02 15:53:34,350 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2018-12-02 15:53:34,351 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,353 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Category")
# 2018-12-02 15:53:34,355 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,356 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Category' AND type = 'table'
# 2018-12-02 15:53:34,358 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,360 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Category")
# 2018-12-02 15:53:34,362 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,364 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Category' AND type = 'table'
# 2018-12-02 15:53:34,365 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,369 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Category")
# 2018-12-02 15:53:34,371 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,372 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Category")
# 2018-12-02 15:53:34,378 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,379 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Category' AND type = 'table'
# 2018-12-02 15:53:34,381 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,385 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Customer")
# 2018-12-02 15:53:34,387 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,389 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Customer' AND type = 'table'
# 2018-12-02 15:53:34,390 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,392 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Customer")
# 2018-12-02 15:53:34,393 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,395 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Customer' AND type = 'table'
# 2018-12-02 15:53:34,396 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,397 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Customer")
# 2018-12-02 15:53:34,397 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,398 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Customer")
# 2018-12-02 15:53:34,399 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,399 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("sqlite_autoindex_Customer_1")
# 2018-12-02 15:53:34,400 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,401 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Customer' AND type = 'table'
# 2018-12-02 15:53:34,401 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,403 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("CustomerCustomerDemo")
# 2018-12-02 15:53:34,403 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,405 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'CustomerCustomerDemo' AND type = 'table'
# 2018-12-02 15:53:34,405 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,406 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("CustomerCustomerDemo")
# 2018-12-02 15:53:34,407 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,407 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'CustomerCustomerDemo' AND type = 'table'
# 2018-12-02 15:53:34,408 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,409 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("CustomerCustomerDemo")
# 2018-12-02 15:53:34,409 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,410 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("CustomerCustomerDemo")
# 2018-12-02 15:53:34,411 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,412 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("sqlite_autoindex_CustomerCustomerDemo_1")
# 2018-12-02 15:53:34,412 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,413 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'CustomerCustomerDemo' AND type = 'table'
# 2018-12-02 15:53:34,414 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,415 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("CustomerDemographic")
# 2018-12-02 15:53:34,415 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,445 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'CustomerDemographic' AND type = 'table'
# 2018-12-02 15:53:34,446 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,448 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("CustomerDemographic")
# 2018-12-02 15:53:34,449 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,450 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'CustomerDemographic' AND type = 'table'
# 2018-12-02 15:53:34,450 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,451 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("CustomerDemographic")
# 2018-12-02 15:53:34,452 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,453 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("CustomerDemographic")
# 2018-12-02 15:53:34,453 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,455 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("sqlite_autoindex_CustomerDemographic_1")
# 2018-12-02 15:53:34,455 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,456 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'CustomerDemographic' AND type = 'table'
# 2018-12-02 15:53:34,457 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,458 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Employee")
# 2018-12-02 15:53:34,458 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,461 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Employee' AND type = 'table'
# 2018-12-02 15:53:34,461 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,463 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Employee")
# 2018-12-02 15:53:34,463 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,464 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Employee' AND type = 'table'
# 2018-12-02 15:53:34,465 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,466 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Employee")
# 2018-12-02 15:53:34,466 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,467 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Employee")
# 2018-12-02 15:53:34,468 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,468 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Employee' AND type = 'table'
# 2018-12-02 15:53:34,469 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,471 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("EmployeeTerritory")
# 2018-12-02 15:53:34,472 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,474 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'EmployeeTerritory' AND type = 'table'
# 2018-12-02 15:53:34,474 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,475 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("EmployeeTerritory")
# 2018-12-02 15:53:34,476 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,477 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'EmployeeTerritory' AND type = 'table'
# 2018-12-02 15:53:34,478 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,479 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("EmployeeTerritory")
# 2018-12-02 15:53:34,479 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,480 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("EmployeeTerritory")
# 2018-12-02 15:53:34,481 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,482 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("sqlite_autoindex_EmployeeTerritory_1")
# 2018-12-02 15:53:34,482 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,483 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'EmployeeTerritory' AND type = 'table'
# 2018-12-02 15:53:34,484 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,485 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Order")
# 2018-12-02 15:53:34,485 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,487 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Order' AND type = 'table'
# 2018-12-02 15:53:34,488 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,489 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Order")
# 2018-12-02 15:53:34,490 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,491 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Order' AND type = 'table'
# 2018-12-02 15:53:34,491 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,492 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Order")
# 2018-12-02 15:53:34,493 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,494 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Order")
# 2018-12-02 15:53:34,494 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,495 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Order' AND type = 'table'
# 2018-12-02 15:53:34,496 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,497 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("OrderDetail")
# 2018-12-02 15:53:34,498 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,529 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'OrderDetail' AND type = 'table'
# 2018-12-02 15:53:34,530 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,531 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("OrderDetail")
# 2018-12-02 15:53:34,532 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,533 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'OrderDetail' AND type = 'table'
# 2018-12-02 15:53:34,533 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,534 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("OrderDetail")
# 2018-12-02 15:53:34,535 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,536 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("OrderDetail")
# 2018-12-02 15:53:34,537 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,537 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("sqlite_autoindex_OrderDetail_1")
# 2018-12-02 15:53:34,538 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,539 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'OrderDetail' AND type = 'table'
# 2018-12-02 15:53:34,540 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,541 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Product")
# 2018-12-02 15:53:34,542 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,543 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Product' AND type = 'table'
# 2018-12-02 15:53:34,544 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,545 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Product")
# 2018-12-02 15:53:34,546 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,547 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Product' AND type = 'table'
# 2018-12-02 15:53:34,547 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,548 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Product")
# 2018-12-02 15:53:34,549 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,550 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Product")
# 2018-12-02 15:53:34,550 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,551 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Product' AND type = 'table'
# 2018-12-02 15:53:34,552 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,553 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Region")
# 2018-12-02 15:53:34,554 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,555 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Region' AND type = 'table'
# 2018-12-02 15:53:34,556 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,557 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Region")
# 2018-12-02 15:53:34,558 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,563 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Region' AND type = 'table'
# 2018-12-02 15:53:34,564 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,565 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Region")
# 2018-12-02 15:53:34,565 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,566 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Region")
# 2018-12-02 15:53:34,567 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,568 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Region' AND type = 'table'
# 2018-12-02 15:53:34,568 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,570 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Shipper")
# 2018-12-02 15:53:34,570 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,572 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Shipper' AND type = 'table'
# 2018-12-02 15:53:34,572 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,574 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Shipper")
# 2018-12-02 15:53:34,574 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,575 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Shipper' AND type = 'table'
# 2018-12-02 15:53:34,576 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,577 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Shipper")
# 2018-12-02 15:53:34,577 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,578 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Shipper")
# 2018-12-02 15:53:34,579 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,580 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Shipper' AND type = 'table'
# 2018-12-02 15:53:34,580 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,582 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Supplier")
# 2018-12-02 15:53:34,582 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,584 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Supplier' AND type = 'table'
# 2018-12-02 15:53:34,585 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,586 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Supplier")
# 2018-12-02 15:53:34,634 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,635 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Supplier' AND type = 'table'
# 2018-12-02 15:53:34,635 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,636 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Supplier")
# 2018-12-02 15:53:34,637 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,638 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Supplier")
# 2018-12-02 15:53:34,639 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,639 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Supplier' AND type = 'table'
# 2018-12-02 15:53:34,640 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,642 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Territory")
# 2018-12-02 15:53:34,642 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,644 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Territory' AND type = 'table'
# 2018-12-02 15:53:34,644 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,645 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Territory")
# 2018-12-02 15:53:34,646 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,647 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Territory' AND type = 'table'
# 2018-12-02 15:53:34,647 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,648 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Territory")
# 2018-12-02 15:53:34,649 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,650 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Territory")
# 2018-12-02 15:53:34,650 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,651 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("sqlite_autoindex_Territory_1")
# 2018-12-02 15:53:34,652 INFO sqlalchemy.engine.base.Engine ()
# 2018-12-02 15:53:34,653 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Territory' AND type = 'table'
# 2018-12-02 15:53:34,653 INFO sqlalchemy.engine.base.Engine ()

# %% [markdown]
# Now that we have some mappings set up, we can make use of `session.query()` help us query our database!
#
# ### Writing Basic Queries
#
# Let's use the `query()` object to get all the employees from the `'Employee'` table.
#
# In the cell below:
#
# * Create a for loop that iterates through the results returned by a `session.query()` of the Employee table (pass this as a variable, not a string).
# * Order the results by the Employee's `.HireDate` attribute.
# * Print the last name, first name, and hire date of each employee.

# %%
for employee in session.query(Employee).order_by(Employee.HireDate):
    print(employee.LastName, employee.FirstName, employee.HireDate)
# Out:
# 2018-12-02 15:53:42,846 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-12-02 15:53:42,849 INFO sqlalchemy.engine.base.Engine SELECT "Employee"."Id" AS "Employee_Id", "Employee"."LastName" AS "Employee_LastName", "Employee"."FirstName" AS "Employee_FirstName", "Employee"."Title" AS "Employee_Title", "Employee"."TitleOfCourtesy" AS "Employee_TitleOfCourtesy", "Employee"."BirthDate" AS "Employee_BirthDate", "Employee"."HireDate" AS "Employee_HireDate", "Employee"."Address" AS "Employee_Address", "Employee"."City" AS "Employee_City", "Employee"."Region" AS "Employee_Region", "Employee"."PostalCode" AS "Employee_PostalCode", "Employee"."Country" AS "Employee_Country", "Employee"."HomePhone" AS "Employee_HomePhone", "Employee"."Extension" AS "Employee_Extension", "Employee"."Photo" AS "Employee_Photo", "Employee"."Notes" AS "Employee_Notes", "Employee"."ReportsTo" AS "Employee_ReportsTo", "Employee"."PhotoPath" AS "Employee_PhotoPath"
# FROM "Employee" ORDER BY "Employee"."HireDate"
# 2018-12-02 15:53:42,849 INFO sqlalchemy.engine.base.Engine ()
# Leverling Janet 2024-04-01
# Davolio Nancy 2024-05-01
# Fuller Andrew 2024-08-14
# Peacock Margaret 2025-05-03
# Buchanan Steven 2025-10-17
# Suyama Michael 2025-10-17
# King Robert 2026-01-02
# Callahan Laura 2026-03-05
# Dodsworth Anne 2026-11-15

# %% [markdown]
# ### Implicit JOINs using `.filter()`
#
# One great benefit of using `session.query()` to query our data is that we can easily execute **_implicit joins_** by making use of the `.filter()` method.
#
# So far we've only explicitly specified mappings for the `Employee` and `Customer` classes.  We'll need to do this now for the `Product` and `Category` classes before we can use them with `session.query()`.
#
# In the cell below, set the mappings for `Product` and `Category`.
#
# **_HINT:_** This will look just like the last line of the code cell where we declared our mappings previously.  No need to repeat all the steps for getting metadata and creating a `Base` class. Just set the mappings!

# %%
Product, Category = Base.classes.Product, Base.classes.Category

# %% [markdown]
# Great!
#
# Now, in the cell below:
#
# * Create a for loop that iterates through all results returned from a query of Products and Categories
# * Use the `.filter()` method to only include cases where the Product's `.CategoryID` matches the Category's `.Id` attribute.
# * Print out the name of each product, followed by the name of the category that it belongs to.

# %%
for i,j in session.query(Product, Category).filter(Product.CategoryId == Category.Id):
    print(i.ProductName,':', j.CategoryName)
# Out:
# 2018-12-02 15:53:49,680 INFO sqlalchemy.engine.base.Engine SELECT "Product"."Id" AS "Product_Id", "Product"."ProductName" AS "Product_ProductName", "Product"."SupplierId" AS "Product_SupplierId", "Product"."CategoryId" AS "Product_CategoryId", "Product"."QuantityPerUnit" AS "Product_QuantityPerUnit", "Product"."UnitPrice" AS "Product_UnitPrice", "Product"."UnitsInStock" AS "Product_UnitsInStock", "Product"."UnitsOnOrder" AS "Product_UnitsOnOrder", "Product"."ReorderLevel" AS "Product_ReorderLevel", "Product"."Discontinued" AS "Product_Discontinued", "Category"."Id" AS "Category_Id", "Category"."CategoryName" AS "Category_CategoryName", "Category"."Description" AS "Category_Description"
# FROM "Product", "Category"
# WHERE "Product"."CategoryId" = "Category"."Id"
# 2018-12-02 15:53:49,681 INFO sqlalchemy.engine.base.Engine ()
# Chai : Beverages
# Chang : Beverages
# Aniseed Syrup : Condiments
# Chef Anton's Cajun Seasoning : Condiments
# Chef Anton's Gumbo Mix : Condiments
# Grandma's Boysenberry Spread : Condiments
# Uncle Bob's Organic Dried Pears : Produce
# Northwoods Cranberry Sauce : Condiments
# Mishi Kobe Niku : Meat/Poultry
# Ikura : Seafood
# Queso Cabrales : Dairy Products
# Queso Manchego La Pastora : Dairy Products
# Konbu : Seafood
# Tofu : Produce
# Genen Shouyu : Condiments
# Pavlova : Confections
# Alice Mutton : Meat/Poultry
# Carnarvon Tigers : Seafood
# Teatime Chocolate Biscuits : Confections
# Sir Rodney's Marmalade : Confections
# Sir Rodney's Scones : Confections
# Gustaf's Knäckebröd : Grains/Cereals
# Tunnbröd : Grains/Cereals
# Guaraná Fantástica : Beverages
# NuNuCa Nuß-Nougat-Creme : Confections
# Gumbär Gummibärchen : Confections
# Schoggi Schokolade : Confections
# Rössle Sauerkraut : Produce
# Thüringer Rostbratwurst : Meat/Poultry
# Nord-Ost Matjeshering : Seafood
# Gorgonzola Telino : Dairy Products
# Mascarpone Fabioli : Dairy Products
# Geitost : Dairy Products
# Sasquatch Ale : Beverages
# Steeleye Stout : Beverages
# Inlagd Sill : Seafood
# Gravad lax : Seafood
# Côte de Blaye : Beverages
# Chartreuse verte : Beverages
# Boston Crab Meat : Seafood
# Jack's New England Clam Chowder : Seafood
# Singaporean Hokkien Fried Mee : Grains/Cereals
# Ipoh Coffee : Beverages
# Gula Malacca : Condiments
# Rogede sild : Seafood
# Spegesild : Seafood
# Zaanse koeken : Confections
# Chocolade : Confections
# Maxilaku : Confections
# Valkoinen suklaa : Confections
# Manjimup Dried Apples : Produce
# Filo Mix : Grains/Cereals
# Perth Pasties : Meat/Poultry
# Tourtière : Meat/Poultry
# Pâté chinois : Meat/Poultry
# Gnocchi di nonna Alice : Grains/Cereals
# Ravioli Angelo : Grains/Cereals
# Escargots de Bourgogne : Seafood
# Raclette Courdavault : Dairy Products
# Camembert Pierrot : Dairy Products
# Sirop d'érable : Condiments
# Tarte au sucre : Confections
# Vegie-spread : Condiments
# Wimmers gute Semmelknödel : Grains/Cereals
# Louisiana Fiery Hot Pepper Sauce : Condiments
# Louisiana Hot Spiced Okra : Condiments
# Laughing Lumberjack Lager : Beverages
# Scottish Longbreads : Confections
# Gudbrandsdalsost : Dairy Products
# Outback Lager : Beverages
# Flotemysost : Dairy Products
# Mozzarella di Giovanni : Dairy Products
# Röd Kaviar : Seafood
# Longlife Tofu : Produce
# Rhönbräu Klosterbier : Beverages
# Lakkalikööri : Beverages
# Original Frankfurter grüne Soße : Condiments
# C:\Users\Learn.co\Anaconda\Anaconda3\lib\site-packages\sqlalchemy\sql\sqltypes.py:603: SAWarning: Dialect sqlite+pysqlite does *not* support Decimal objects natively, and SQLAlchemy must convert from floating point - rounding errors and other issues may occur. Please consider storing Decimal numbers as strings or integers on this platform for lossless storage.
#   'storage.' % (dialect.name, dialect.driver))

# %% [markdown]
# ## Summary
#
# Great job! You've just used SQLAlchemy to work with a sample production database. Note that there are many, many more awesome things that SQLAlchemy can do, but they're outside the scope of this lesson.  However, if you're interested in learning more, don't be afraid to take a look at the [SQLAlchemy documentation](https://docs.sqlalchemy.org/en/latest/orm/tutorial.html) and work through some tutorials in your spare time!
